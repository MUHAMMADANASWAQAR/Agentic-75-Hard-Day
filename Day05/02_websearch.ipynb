# %%
from tavily import TavilyClient

# %%
tavily_client = TavilyClient(api_key="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")
response = tavily_client.search("Who is Leo Messi?")

print(response)
